# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import librosa
plt.style.use('seaborn')
import sys
sys.path.insert(0, '/home/david/Galvanize/capstones/music_genres/src')
from helper_funcs import get_track_ids, create_array, splitDataFrameIntoSmaller, unison_shuffled_copies

# %%
tracks = pd.read_csv('../data/fma_metadata/tracks.csv', index_col=0, header=[0,1])

# %%
df = tracks[[('set', 'split'), ('set', 'subset'), ('track', 'genre_top')]]
df = df[df[('set','subset')] == 'small']
df['track_id'] = df.index
df.head()
# Out:
#                set            track track_id
#              split subset genre_top
# track_id
# 2         training  small   Hip-Hop        2
# 5         training  small   Hip-Hop        5
# 10        training  small       Pop       10
# 140       training  small      Folk      140
# 141       training  small      Folk      141

# %%
audio_dir = '../data/fma_small'
track_ids = get_track_ids(audio_dir)
len(track_ids)
# Out:
# 8000

# %%
genre_dict = {'Electronic':1, 'Experimental':2, 'Folk':3, 'Hip-Hop':4, 
               'Instrumental':5,'International':6, 'Pop' :7, 'Rock': 8  }

# %%
train = df[df[('set', 'split')]=='training']
test = df[df[('set', 'split')]=='test']
val = df[df[('set', 'split')]=='validation']

# %%
train.shape
# Out:
# (6400, 4)

# %%
test.shape==val.shape
# Out:
# True

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
X_test, y_test = create_array(test, audio_dir, genre_dict)
# Out:
# /home/david/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /home/david/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /home/david/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /home/david/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /home/david/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
# ...

# %%
print(X_test.shape, y_test.shape)
# Out:
# (800, 640, 128) (800,)

# %%
y_test[:10]
# Out:
# array([8, 6, 6, 6, 6, 6, 6, 3, 3, 2])

# %%
np.savez('../saved_variables/test', X_test, y_test)

# %%
X_val, y_val = create_array(val, audio_dir, genre_dict)
# Out:
# Currently processing:  100
# Currently processing:  200
# Currently processing:  300
# Currently processing:  400
# Currently processing:  500
# Currently processing:  600
# Currently processing:  700
# Currently processing:  800

# %%
np.savez('../saved_variables/val_arr', X_val, y_val)

# %%
split_df = splitDataFrameIntoSmaller(train)
train1 = split_df[0]
train2 = split_df[1]
train3 = split_df[2]
train4 = split_df[3]
train1.shape==train2.shape==train3.shape==train4.shape
# Out:
# True

# %%
X_train1, y_train1 = create_array(train1, audio_dir, genre_dict)
# Out:
# Currently processing:  100
# Currently processing:  200
# Currently processing:  300
# Currently processing:  400
# Currently processing:  500
# Currently processing:  600
# Currently processing:  700
# Currently processing:  800
# Currently processing:  900
# Currently processing:  1000
# Currently processing:  1100
# Currently processing:  1200
# Currently processing:  1300
# Currently processing:  1400
# Currently processing:  1500
# Currently processing:  1600

# %%
np.savez('../saved_variables/train1_arr', X_train1, y_train1)

# %%
X_train2, y_train2 = create_array(train2, audio_dir, genre_dict)
np.savez('../saved_variables/train2_arr', X_train2, y_train2)
# Out:
# Currently processing:  100
# Currently processing:  200
# Currently processing:  300
# Currently processing:  400
# Currently processing:  500
# Currently processing:  600
# Currently processing:  700
# Currently processing:  800
# Currently processing:  900
# Currently processing:  1000
# Currently processing:  1100
# Currently processing:  1200
# Currently processing:  1300
# Currently processing:  1400
# Currently processing:  1500
# Currently processing:  1600

# %%
X_train3, y_train3 = create_array(train3, audio_dir, genre_dict)
np.savez('../saved_variables/train3_arr', X_train3, y_train3)
# Out:
# Currently processing:  100
# Currently processing:  200
# Couldn't process:  296
# Couldn't process:  297
# Couldn't process:  298
# Currently processing:  300
# Couldn't process:  331
# Currently processing:  400
# Currently processing:  500
# Currently processing:  600
# Couldn't process:  698
# Currently processing:  700
# Currently processing:  800
# Currently processing:  900
# Currently processing:  1000
# Currently processing:  1100
# Currently processing:  1200
# Currently processing:  1300
# Currently processing:  1400
# Currently processing:  1500
# Currently processing:  1600

# %%
X_train4, y_train4 = create_array(train4, audio_dir, genre_dict)
np.savez('../saved_variables/train4_arr', X_train4, y_train4)
# Out:
# Currently processing:  100
# Currently processing:  200
# Currently processing:  300
# Currently processing:  400
# Currently processing:  500
# Currently processing:  600
# Currently processing:  700
# Currently processing:  800
# Couldn't process:  812
# Currently processing:  900
# Currently processing:  1000
# Currently processing:  1100
# Currently processing:  1200
# Currently processing:  1300
# Currently processing:  1400
# Currently processing:  1500
# Currently processing:  1600

# %%
npzfile = np.load('../saved_variables/train1_arr.npz')
X_train1 = npzfile['arr_0']
y_train1 = npzfile['arr_1']
X_train1.shape[0]==y_train1.shape[0]
# Out:
# True

# %%
npzfile = np.load('../saved_variables/train2_arr.npz')
X_train2 = npzfile['arr_0']
y_train2 = npzfile['arr_1']
X_train2.shape[0]==y_train2.shape[0]
# Out:
# True

# %%
npzfile = np.load('../saved_variables/train3_arr.npz')
X_train3 = npzfile['arr_0']
y_train3 = npzfile['arr_1']
X_train3.shape[0]==y_train3.shape[0]
# Out:
# True

# %%
npzfile = np.load('../saved_variables/train4_arr.npz')
X_train4 = npzfile['arr_0']
y_train4 = npzfile['arr_1']
X_train4.shape[0]==y_train4.shape[0]
# Out:
# True

# %%
npzfile = np.load('../saved_variables/val_arr.npz')
X_val = npzfile['arr_0']
y_val = npzfile['arr_1']
X_val.shape[0]==y_val.shape[0]
# Out:
# True

# %%
X_train = np.concatenate((X_train1, X_train2, X_train3, X_train4), axis = 0)
y_train = np.concatenate((y_train1, y_train2, y_train3, y_train4), axis = 0)
print(X_train.shape, y_train.shape)
# Out:
# (6394, 640, 128) (6394,)

# %%
print(np.amin(X_train), np.amax(X_train), np.mean(X_train))
y_train = y_train -1
y_val = y_val -1
print(np.amin(y_train), np.amax(y_train), np.mean(y_train))
# Out:
# -80.0 3.814697265625e-06 -44.08259345747434
# 0 7 3.500625586487332

# %%
X_train_raw = librosa.core.db_to_power(X_train, ref=1.0)
X_train_log = np.log(X_train_raw)

# %%
X_val_raw = librosa.core.db_to_power(X_val, ref=1.0)
X_val_log = np.log(X_val_raw)

# %%
X_train, y_train = unison_shuffled_copies(X_train, y_train)
X_val, y_val = unison_shuffled_copies(X_val, y_val)

# %%
print( X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# Shapes are:  (6394, 640, 128) (800, 640, 128) (6394,) (800,)

# %%
np.savez('../saved_variables/train', X_train, y_train)
np.savez('../saved_variables/validation', X_val, y_val)

# %%
npzfile = np.load('../saved_variables/test_arr.npz')
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
y_test -= 1
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
X_test = np.log(X_test_raw)
np.savez('../saved_variables/test.npz', X_test, y_test)
