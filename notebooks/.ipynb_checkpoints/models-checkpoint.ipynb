# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop
from keras import regularizers
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import librosa
import librosa.display
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns

# %%
genre_dict = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }
reverse_dict = {v: k for k, v in genre_dict.items()}

# %%
npzfile = np.load('../saved_variables/train.npz')
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('../saved_variables/validation.npz')
X_val = npzfile['arr_0']
y_val = npzfile['arr_1']
print(X_val.shape, y_val.shape)
# Out:
# (800, 640, 128) (800, 8)

# %%
npzfile = np.load('../saved_variables/test.npz')
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
y_test -= 1
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
X_test = np.log(X_test_raw)
np.savez('../saved_variables/test.npz', X_test, y_test)

# %%
spectogram = X_train[5]
genre = np.argmax(y_train[5])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title(reverse_dict[genre])
plt.tight_layout()

# %%
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]
n_layers = 3
filter_length = 5
conv_filter_count = 56
batch_size = 32
lstm_count = 96
epoch_count = 70
n_hidden = 64
L2_regularization = 0.001
input_shape = (None, n_features)
model_input = Input(input_shape, name='input')
print('Building model...')
layer = model_input

for i in range(n_layers):
    layer = Conv1D(
            filters=conv_filter_count,
            kernel_size=filter_length,
            kernel_regularizer=regularizers.l2(L2_regularization),
            name='convolution_' + str(i + 1)
        )(layer)
    layer = BatchNormalization(momentum=0.9)(layer)
    layer = Activation('relu')(layer)
    layer = MaxPooling1D(2)(layer)
    layer = Dropout(0.4)(layer)

layer = LSTM(lstm_count, return_sequences=False)(layer)
layer = Dropout(0.4)(layer)

layer = Dense(n_hidden, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
layer = Dropout(0.4)(layer)

layer = Dense(num_classes)(layer)
layer = Activation('softmax', name='output_realtime')(layer)
model_output = layer
crnn_model = Model(model_input, model_output)

crnn_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.001), metrics=['accuracy'])
print(crnn_model.summary())
checkpoint_callback = ModelCheckpoint('../saved_variables/crnn_weights.best.hdf5', monitor='val_accuracy', 
                                      verbose=1, save_best_only=True, mode='max')

reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, 
                                      min_delta=0.01, verbose=1)
print('Training...')
crnn_history = crnn_model.fit(X_train, y_train, batch_size=batch_size, epochs=epoch_count,
                    validation_data=(X_val, y_val), verbose=1, 
                    callbacks=[checkpoint_callback, reducelr_callback])
# Out:
# Building model...
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_22 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_22 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_23 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_23 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_24 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_24 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 133,520
# Trainable params: 133,184
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 6394 samples, validate on 800 samples
# Epoch 1/70
# 6394/6394 [==============================] - 161s 25ms/step - loss: 2.1504 - accuracy: 0.2895 - val_loss: 2.0461 - val_accuracy: 0.2900
#
# Epoch 00001: val_accuracy improved from -inf to 0.29000, saving model to ../saved_variables/crnn_weights.best.hdf5
# Epoch 2/70
# 6394/6394 [==============================] - 159s 25ms/step - loss: 1.9827 - accuracy: 0.3514 - val_loss: 2.0054 - val_accuracy: 0.3438
#
# Epoch 00002: val_accuracy improved from 0.29000 to 0.34375, saving model to ../saved_variables/crnn_weights.best.hdf5
# Epoch 3/70
# 6394/6394 [==============================] - 149s 23ms/step - loss: 1.9062 - accuracy: 0.3827 - val_loss: 2.0736 - val_accuracy: 0.3150
#
# Epoch 00003: val_accuracy did not improve from 0.34375
# Epoch 4/70
# 6394/6394 [==============================] - 150s 23ms/step - loss: 1.8479 - accuracy: 0.4016 - val_loss: 1.9623 - val_accuracy: 0.3300
#
# Epoch 00004: val_accuracy did not improve from 0.34375
# Epoch 5/70
# 6394/6394 [==============================] - 153s 24ms/step - loss: 1.8087 - accuracy: 0.4137 - val_loss: 2.0547 - val_accuracy: 0.2788
#
# Epoch 00005: val_accuracy did not improve from 0.34375
# Epoch 6/70
# 6394/6394 [==============================] - 145s 23ms/step - loss: 1.7763 - accuracy: 0.4209 - val_loss: 2.0391 - val_accuracy: 0.2700
#
# Epoch 00006: val_accuracy did not improve from 0.34375
# Epoch 7/70
# 6394/6394 [==============================] - 157s 25ms/step - loss: 1.7351 - accuracy: 0.4410 - val_loss: 1.8829 - val_accuracy: 0.3787
#
# Epoch 00007: val_accuracy improved from 0.34375 to 0.37875, saving model to ../saved_variables/crnn_weights.best.hdf5
# Epoch 8/70
# 6394/6394 [==============================] - 151s 24ms/step - loss: 1.6905 - accuracy: 0.4490 - val_loss: 2.0546 - val_accuracy: 0.3237
#
# Epoch 00008: val_accuracy did not improve from 0.37875
# Epoch 9/70
# 6394/6394 [==============================] - 146s 23ms/step - loss: 1.6726 - accuracy: 0.4672 - val_loss: 1.8138 - val_accuracy: 0.4075
#
# Epoch 00009: val_accuracy improved from 0.37875 to 0.40750, saving model to ../saved_variables/crnn_weights.best.hdf5
# Epoch 10/70
# 6394/6394 [==============================] - 140s 22ms/step - loss: 1.6236 - accuracy: 0.4811 - val_loss: 1.9760 - val_accuracy: 0.3738
#
# Epoch 00010: val_accuracy did not improve from 0.40750
# Epoch 11/70
# 6394/6394 [==============================] - 154s 24ms/step - loss: 1.6230 - accuracy: 0.4850 - val_loss: 1.9493 - val_accuracy: 0.3625
#
# Epoch 00011: val_accuracy did not improve from 0.40750
# Epoch 12/70
# 6394/6394 [==============================] - 153s 24ms/step - loss: 1.6105 - accuracy: 0.4931 - val_loss: 2.0547 - val_accuracy: 0.3262
#
# Epoch 00012: val_accuracy did not improve from 0.40750
# Epoch 13/70
# 6394/6394 [==============================] - 153s 24ms/step - loss: 1.5800 - accuracy: 0.5006 - val_loss: 2.1096 - val_accuracy: 0.3063
#
# Epoch 00013: val_accuracy did not improve from 0.40750
# Epoch 14/70
# 6394/6394 [==============================] - 162s 25ms/step - loss: 1.5422 - accuracy: 0.5106 - val_loss: 3.2942 - val_accuracy: 0.1650
#
# Epoch 00014: val_accuracy did not improve from 0.40750
# Epoch 15/70
# 6394/6394 [==============================] - 157s 25ms/step - loss: 1.5483 - accuracy: 0.5056 - val_loss: 1.8098 - val_accuracy: 0.3725
#
# Epoch 00015: val_accuracy did not improve from 0.40750
# Epoch 16/70
# 6394/6394 [==============================] - 132s 21ms/step - loss: 1.5345 - accuracy: 0.5167 - val_loss: 2.0626 - val_accuracy: 0.3675
#
# Epoch 00016: val_accuracy did not improve from 0.40750
# Epoch 17/70
#  160/6394 [..............................] - ETA: 1:59 - loss: 1.3182 - accuracy: 0.5938

# %%
#model.save_weights('../saved_variables/crnn_weights.hdf5')

# %%
model = load_model('../saved_variables/crnn_weights.hdf5')

# %%
npzfile = np.load('../saved_variables/test.npz')
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# (800, 640, 128) (800,)

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred, labels=list(genre_dict.values()), target_names=genre_dict.keys()))
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.76      0.32      0.45       100
#  Experimental       0.29      0.36      0.32       100
#          Folk       0.15      0.20      0.17       100
#       Hip-Hop       0.62      0.85      0.71       100
#  Instrumental       0.34      0.33      0.33       100
# International       0.44      0.51      0.47       100
#           Pop       0.29      0.28      0.29       100
#          Rock       0.71      0.36      0.48       100
#
#      accuracy                           0.40       800
#     macro avg       0.45      0.40      0.40       800
#  weighted avg       0.45      0.40      0.40       800

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=8)
model.evaluate(X_test, y_test)
# Out:
# 800/800 [==============================] - 5s 7ms/step
# [2.020079345703125, 0.4012500047683716]

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.40125

# %%
mat = confusion_matrix(y_test, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=genre_dict.keys(),
            yticklabels=genre_dict.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
